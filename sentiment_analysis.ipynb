# %%
import pandas as pd
import plotly.express as px
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download(["names","stopwords","state_union","twitter_samples","movie_reviews","averaged_perceptron_tagger","vader_lexicon","punkt" ])
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\josse\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\josse\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package state_union to
# [nltk_data]     C:\Users\josse\AppData\Roaming\nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\josse\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\josse\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\josse\AppData\Roaming\nltk_data...
# ...

# %%
df_complet = pd.read_csv('csv_shipping_comment.csv',low_memory = False)

# %%
df_complet.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1         id  \
# 0          61            61  295562436
# 1         196           196  295562886
# 2         206           206  295563227
# 3         248           248  295563929
# 4         464           464  295563194
#
#                                              comment  \
# 0  Many products available and reasonable shippin...
# 1                                 too high shipments
# 2           Hope delivery is as easy as the ordering
# 3  It says the delivery is free, when you pay, it...
# 4                       Quick order to see delivery?
#
#                                     original_comment  score data_scale  \
# 0  Nombreux produit disponible et frais de port r...     10        NPS
# 1                             spedizioni troppo alte      0        NPS
# 2           Hope delivery is as easy as the ordering      8        NPS
# 3  C'est écrit que la livraison est gratuite, au ...      5        NPS
# ...

# %%
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("Wow, NLTK is really powerful!")
# Out:
# {'neg': 0.0, 'neu': 0.295, 'pos': 0.705, 'compound': 0.8012}

# %%
def positif (sentiment):
    return sia.polarity_scores(sentiment)['pos']

def neutre (sentiment):
    return sia.polarity_scores(sentiment)['neu']

def neg (sentiment):
    return sia.polarity_scores(sentiment)['neg']

def compound (sentiment):
    return sia.polarity_scores(sentiment)['compound']

# %%
df_complet['neg'] =  df_complet['comment'].apply(neg)
df_complet['neu'] =  df_complet['comment'].apply(neutre)
df_complet['pos'] =  df_complet['comment'].apply(positif)
df_complet['compound'] =  df_complet['comment'].apply(compound)

# %%
df_complet[df_complet['id']==369045064]['original_comment']
# Out:
# 1206    JE TROUVE DOMMAGE QUE LES FRAIS DE LIVRAISON S...
# Name: original_comment, dtype: object

# %%
df_complet[['comment','score','neg','neu','pos','compound']][df_complet['compound']<-0.0].sort_values('compound',ascending=True)
# Out:
#                                                 comment  score    neg    neu  \
# 990   I had ordered 3 cubic wall shelves and a plaid...      8  0.159  0.812
# 247   product categories are difficult to find, ever...      5  0.149  0.851
# 640   I wanted to change the delivery address and I ...      2  0.307  0.693
# 259         Having to pay 2 delivery charges is a pain!      7  0.639  0.361
# 436   No place of delivery other than personal addre...     10  0.428  0.572
# ...                                                 ...    ...    ...    ...
# 251   ok no particular problem waiting for delivery ...      7  0.295  0.422
# 413      I like this site the only problem is delivery.      9  0.241  0.536
# 66    It would be convenient to be able to easily lo...      5  0.113  0.812
# 1128  up until now everything perfect, no problem ev...      9  0.295  0.482
# 617   No surprise with shipping costs they are displ...      9  0.165  0.677
#
#         pos  compound
# ...
